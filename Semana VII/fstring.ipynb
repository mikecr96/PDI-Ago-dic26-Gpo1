# %% [markdown]
# # Formateo de strings (f-strings)

# %%
print(r"C:\Users\asjdjaskdaksdkaskdaksd")
# Out:
# C:\Users\asjdjaskdaksdkaskdaksd

# %%
print(f'Hola mundo')
# Out:
# Hola mundo

# %%
nombre = "Miguel"
edad = 100
fuma = False
print('{} tiene {} años y fuma? {}'.format(nombre, edad, fuma))
# Out:
# Miguel tiene 100 años y fuma? False

# %%
print(f'{nombre} tiene {edad} años y fuma? {fuma}')
# Out:
# Miguel tiene 100 años y fuma? False

# %%
print(f'{nombre + ' Camargo'} tiene {edad + 100} años y fuma? {fuma}')
# Out:
# Miguel Camargo tiene 200 años y fuma? False

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
for i in range(10):
    ruido = np.random.randint(256, size=(10, 10))
    plt.imshow(ruido, cmap='gray')
    plt.title(f'Ruido #{i+1}')
    plt.show()
