# %%
import numpy as np
import matplotlib.pyplot as plt

imagen = plt.imread(r"/Users/miguelcamargorojas/Downloads/siames.jpg")

# %%
plt.imshow(imagen)
plt.show()

# %%
plt.imshow(imagen[85:290, 15:230])
plt.show()

# %% [markdown]
# ---

# %%
orange = plt.imread('/Users/miguelcamargorojas/iCloud Drive (Archive)/Documents/UP/PDI - Ago-dic23/images/orange.jpg')

# %%
plt.imshow(orange)
plt.show()
